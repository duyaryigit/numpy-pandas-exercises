# %% [markdown]
# ### Pandas Exercises

# %%
import pandas as pd

# %%
pd.DataFrame({'A': [5,10], 'B': [15,20]}) # 2 Dimensions (column, row)
# Out:
#     A   B
# 0   5  15
# 1  10  20

# %%
pd.Series([1,2,3,4,5]) # 1 Dimension
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series([10,20,30], index = ['A','B','C'], name = 'example')
# Out:
# A    10
# B    20
# C    30
# Name: example, dtype: int64

# %%
df = pd.read_csv('winemag-data-130k-v2.csv')

# %%
df
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
df.head() # 5 column
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
df.shape
# Out:
# (129971, 14)

# %%
df_arrange = pd.read_csv('winemag-data-130k-v2.csv', index_col=0)

# %%
df_arrange.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
df_arrange.country
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
df_arrange.iloc[3] # Select row and values
# Out:
# country                                                                 US
# description              Pineapple rind, lemon pith and orange blossom ...
# designation                                           Reserve Late Harvest
# points                                                                  87
# price                                                                 13.0
# province                                                          Michigan
# region_1                                               Lake Michigan Shore
# region_2                                                               NaN
# taster_name                                             Alexander Peartree
# taster_twitter_handle                                                  NaN
# title                    St. Julian 2013 Reserve Late Harvest Riesling ...
# variety                                                           Riesling
# ...

# %%
df_arrange.iloc[:,0] # Select all data according to index 0
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
df_arrange.iloc[2:5,3] # Select 3 data according to index 3
# Out:
# 2    87
# 3    87
# 4    87
# Name: points, dtype: int64

# %%
df_arrange.iloc[[0,1,3,5],3]
# Out:
# 0    87
# 1    87
# 3    87
# 5    87
# Name: points, dtype: int64

# %%
df_arrange.iloc[-7:,0] # Select 7 pieces of data from the end according to index 0
# Out:
# 129964     France
# 129965     France
# 129966    Germany
# 129967         US
# 129968     France
# 129969     France
# 129970     France
# Name: country, dtype: object

# %%
df_arrange.loc[3,'country']
# Out:
# 'US'

# %%
df_arrange.loc[:,['country','price','designation']]
# Out:
#          country  price                             designation
# 0          Italy    NaN                            Vulkà Bianco
# 1       Portugal   15.0                                Avidagos
# 2             US   14.0                                     NaN
# 3             US   13.0                    Reserve Late Harvest
# 4             US   65.0      Vintner's Reserve Wild Child Block
# ...          ...    ...                                     ...
# 129966   Germany   28.0  Brauneberger Juffer-Sonnenuhr Spätlese
# 129967        US   75.0                                     NaN
# 129968    France   30.0                                   Kritt
# 129969    France   32.0                                     NaN
# 129970    France   21.0           Lieu-dit Harth Cuvée Caroline
#
# [129971 rows x 3 columns]

# %%
df_arrange.loc[:5,['country','price','designation']]
# Out:
#     country  price                         designation
# 0     Italy    NaN                        Vulkà Bianco
# 1  Portugal   15.0                            Avidagos
# 2        US   14.0                                 NaN
# 3        US   13.0                Reserve Late Harvest
# 4        US   65.0  Vintner's Reserve Wild Child Block
# 5     Spain   15.0                        Ars In Vitro

# %%
df_arrange.set_index('title')
# Out:
#                                                      country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                      Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       Portugal
# Rainstorm 2013 Pinot Gris (Willamette Valley)             US
# St. Julian 2013 Reserve Late Harvest Riesling (...        US
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...        US
# ...                                                      ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 B...   Germany
# Citation 2004 Pinot Noir (Oregon)                         US
# Domaine Gresser 2013 Kritt Gewurztraminer (Alsace)    France
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)         France
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...    France
#
#                                                                                           description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                   Aromas include tropical fruit, broom, brimston...
# ...

# %%
df_arrange.country == 'France'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 129966    False
# 129967    False
# 129968     True
# 129969     True
# 129970     True
# Name: country, Length: 129971, dtype: bool

# %%
df_arrange.loc[df_arrange.country == 'France']
# Out:
#        country                                        description  \
# 7       France  This dry and restrained wine offers spice in p...
# 9       France  This has great depth of flavor with its fresh ...
# 11      France  This is a dry wine, very spicy, with a tight, ...
# 30      France  Red cherry fruit comes laced with light tannin...
# 42      France  This is a festive wine, with soft, ripe fruit ...
# ...        ...                                                ...
# 129964  France  Initially quite muted, this wine slowly develo...
# 129965  France  While it's rich, this beautiful dry wine also ...
# 129968  France  Well-drained gravel soil gives this wine its c...
# 129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price    province  \
# 7                                 NaN      87   24.0      Alsace
# ...

# %%
df_arrange.loc[(df_arrange.country == 'France') & (df_arrange.points == 90)]
# Out:
#        country                                        description  \
# 138     France  Mid-gold color. Very mineral driven with subtl...
# 139     France  Beautiful deep gold color. Intense, concentrat...
# 143     France  Rich gold in color. Broad, layered aromas of v...
# 209     France  Intriguing, thought provoking and complex, thi...
# 211     France  This is taut and sinewy in profile, but shows ...
# ...        ...                                                ...
# 129964  France  Initially quite muted, this wine slowly develo...
# 129965  France  While it's rich, this beautiful dry wine also ...
# 129968  France  Well-drained gravel soil gives this wine its c...
# 129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                                     designation  points  price      province  \
# 138                                   Crustacés      90   10.0        Alsace
# ...

# %%
df_arrange.loc[df_arrange.country.isin(['France','US'])]
# Out:
#        country                                        description  \
# 2           US  Tart and snappy, the flavors of lime flesh and...
# 3           US  Pineapple rind, lemon pith and orange blossom ...
# 4           US  Much like the regular bottling from 2012, this...
# 7       France  This dry and restrained wine offers spice in p...
# 9       France  This has great depth of flavor with its fresh ...
# ...        ...                                                ...
# 129965  France  While it's rich, this beautiful dry wine also ...
# 129967      US  Citation is given as much as a decade of bottl...
# 129968  France  Well-drained gravel soil gives this wine its c...
# 129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                                designation  points  price  province  \
# 2                                      NaN      87   14.0    Oregon
# ...

# %%
df_arrange.loc[df_arrange.designation.notnull()]
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# 5          Spain  Blackberry and raspberry aromas show a typical...
# ...          ...                                                ...
# 129964    France  Initially quite muted, this wine slowly develo...
# 129965    France  While it's rich, this beautiful dry wine also ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...
